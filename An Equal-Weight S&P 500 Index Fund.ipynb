# %%
import numpy as np
import pandas as pd
import requests
import xlsxwriter
import math

# %%
stocks=pd.read_csv('/content/sp_500_stocks.csv')

# %%
stocks
# Out:
#   Ticker
# 5    ABC

# %%
from hello import IEX_CLOUD_API_TOKEN

# %%
symbol='A'
api_url = f'https://cloud.iexapis.com/stable/stock/{symbol}/quote?token={IEX_CLOUD_API_TOKEN}'
data = requests.get(api_url).json()
print(data)
# Out:
# {'avgTotalVolume': 2038000, 'calculationPrice': 'tops', 'change': -1.55, 'changePercent': -0.01486, 'close': None, 'closeSource': 'official', 'closeTime': None, 'companyName': 'Agilent Technologies Inc.', 'currency': 'USD', 'delayedPrice': None, 'delayedPriceTime': None, 'extendedChange': None, 'extendedChangePercent': None, 'extendedPrice': None, 'extendedPriceTime': None, 'high': None, 'highSource': '15 minute delayed price', 'highTime': 1698431979901, 'iexAskPrice': 112.27, 'iexAskSize': 149, 'iexBidPrice': 94.49, 'iexBidSize': 101, 'iexClose': 102.76, 'iexCloseTime': 1698432848896, 'iexLastUpdated': 1698432848896, 'iexMarketPercent': 0.031728503720063195, 'iexOpen': 104.665, 'iexOpenTime': 1698413424204, 'iexRealtimePrice': 102.76, 'iexRealtimeSize': 14, 'iexVolume': 34824, 'lastTradeTime': 1698432848896, 'latestPrice': 102.76, 'latestSource': 'IEX real time price', 'latestTime': '2:54:08 PM', 'latestUpdate': 1698432848896, 'latestVolume': None, 'low': None, 'lowSource': '15 minu
# ...

# %%
my_columns=['Ticker','Stock Price','Market Capitalization','Number of Shares to Buy']
final_dataframe=pd.DataFrame(columns=my_columns)

# %%
final_stocks=pd.DataFrame(columns=['Ticker'])

# %%
for stock in stocks['Ticker']:
  count=0
  api_url= f'https://cloud.iexapis.com/stable/stock/{stock}/quote?token={IEX_CLOUD_API_TOKEN}'
  data=requests.get(api_url)
  if data.status_code==200:
    final_stocks=final_stocks.append(pd.Series([stock],index=['Ticker']),ignore_index=True)
  else:
    count+=1
# Out:
# <ipython-input-25-9b3e0b8626c7>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_stocks=final_stocks.append(pd.Series([stock],index=['Ticker']),ignore_index=True)
# <ipython-input-25-9b3e0b8626c7>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_stocks=final_stocks.append(pd.Series([stock],index=['Ticker']),ignore_index=True)
# <ipython-input-25-9b3e0b8626c7>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_stocks=final_stocks.append(pd.Series([stock],index=['Ticker']),ignore_index=True)
# <ipython-input-25-9b3e0b8626c7>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
for stock in final_stocks['Ticker']:
    print(stock)
    api_url = f'https://cloud.iexapis.com/stable/stock/{stock}/quote?token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(api_url)
    if data.status_code == 200:
        data=data.json()
        final_dataframe=final_dataframe.append(
        pd.Series(
            [stock,
            data['latestPrice']
            ,data['marketCap'],
            'N/A']
,index=my_columns
        )
        ,ignore_index=True
    )
# Out:
# A
# <ipython-input-33-c29f3281aa83>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe=final_dataframe.append(
# AAL
# <ipython-input-33-c29f3281aa83>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe=final_dataframe.append(
# AAP
# <ipython-input-33-c29f3281aa83>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe=final_dataframe.append(
# AAPL
# <ipython-input-33-c29f3281aa83>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_dataframe=final_dataframe.append(
# ABBV
# ...

# %%
final_dataframe
# Out:
#     Ticker  Stock Price Market Capitalization Number of Shares to Buy
# 0        A      102.690           30045787064                     N/A
# 1      AAL       10.925            7139930509                     N/A
# 2      AAP       50.030            2975297158                     N/A
# 3     AAPL      167.910         2625143895120                     N/A
# 4     ABBV      137.280          242305608230                     N/A
# ..     ...          ...                   ...                     ...
# 491    YUM      119.710           33544092449                     N/A
# 492    ZBH      102.790           21479423334                     N/A
# 493   ZBRA      206.840           10618827210                     N/A
# 494   ZION       29.360            4349541105                     N/A
# 495    ZTS      155.370           71519437530                     N/A
#
# [496 rows x 4 columns]

# %%
final_dataframe.to_csv('/content/updatedstocks.csv')

# %%
from google.colab import files
files.download('updatedstocks.csv')

# %%
def chunks(lst,n):
  for i in range(0,len(lst),n):
    yield lst[i:i+n]

# %%
symbol_groups=list(chunks(final_stocks['Ticker'],100))
symbol_groups
# Out:
# [0         A
#  1       AAL
#  2       AAP
#  3      AAPL
#  4      ABBV
#        ...
#  95      CLX
#  96      CMA
#  97    CMCSA
#  98      CME
#  99      CMG
#  Name: Ticker, Length: 100, dtype: object,
#  100     CMI
#  101     CMS
#  102     CNC
#  103     CNP
#  104     COF
#         ...
#  195    GILD
#  196     GIS
#  197      GL
#  198     GLW
#  199      GM
#  Name: Ticker, Length: 100, dtype: object,
#  200     GOOG
#  201    GOOGL
#  202      GPC
#  203      GPN
#  204      GPS
#         ...
#  295      MCK
#  296      MCO
#  297     MDLZ
#  298      MDT
#  299      MET
#  Name: Ticker, Length: 100, dtype: object,
#  300     MGM
#  301     MHK
#  302     MKC
#  303    MKTX
#  304     MLM
#         ...
#  395    ROST
#  396     RSG
#  397     RTX
#  398    SBAC
#  399    SBUX
#  Name: Ticker, Length: 100, dtype: object,
#  400    SCHW
#  401     SEE
#  402     SHW
#  403    SIVB
#  404     SJM
#         ...
#  491     YUM
#  492     ZBH
#  493    ZBRA
#  494    ZION
# ...

# %%
symbol_strings=[]
for i in range(len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
print(symbol_strings)
# Out:
# ['A,AAL,AAP,AAPL,ABBV,ABMD,ABT,ACN,ADBE,ADI,ADM,ADP,ADSK,AEE,AEP,AES,AFL,AIG,AIV,AIZ,AJG,AKAM,ALB,ALGN,ALK,ALL,ALLE,ALXN,AMAT,AMCR,AMD,AME,AMGN,AMP,AMT,AMZN,ANET,ANSS,AON,AOS,APA,APD,APH,APTV,ARE,ATO,ATVI,AVB,AVGO,AVY,AWK,AXP,AZO,BA,BAC,BAX,BBY,BDX,BEN,BF.B,BIIB,BIO,BK,BKNG,BKR,BLK,BLL,BMY,BR,BRK.B,BSX,BWA,BXP,C,CAG,CAH,CARR,CAT,CB,CBOE,CBRE,CCI,CCL,CDNS,CDW,CE,CERN,CF,CFG,CHD,CHRW,CHTR,CI,CINF,CL,CLX,CMA,CMCSA,CME,CMG', 'CMI,CMS,CNC,CNP,COF,COG,COO,COP,COST,COTY,CPB,CPRT,CRM,CSCO,CSX,CTAS,CTL,CTSH,CTVA,CTXS,CVS,CVX,CXO,D,DAL,DD,DE,DFS,DG,DGX,DHI,DHR,DIS,DISCK,DISH,DLR,DLTR,DOV,DOW,DPZ,DRE,DRI,DTE,DUK,DVA,DVN,DXC,DXCM,EA,EBAY,ECL,ED,EFX,EIX,EL,EMN,EMR,EOG,EQIX,EQR,ES,ESS,ETFC,ETN,ETR,EVRG,EW,EXC,EXPD,EXPE,EXR,F,FANG,FAST,FB,FCX,FDX,FE,FFIV,FIS,FISV,FITB,FLIR,FLS,FLT,FMC,FOX,FOXA,FRC,FRT,FTI,FTNT,FTV,GD,GE,GILD,GIS,GL,GLW,GM', 'GOOG,GOOGL,GPC,GPN,GPS,GRMN,GS,GWW,HAL,HAS,HBAN,HBI,HCA,HD,HES,HIG,HII,HLT,HOLX,HON,HPE,HPQ,HRB,HRL,HSIC,HST,HSY,HUM,HWM,IBM,ICE,IDXX,IEX,IFF,ILMN,INCY,INFO,IN
# ...

# %%
final_dataframe1=pd.DataFrame(columns=my_columns)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
for symbol_string in symbol_strings:
#     print(symbol_strings)
    batch_api_call_url = f'https://cloud.iexapis.com/stable/stock/market/batch/?types=quote&symbols={symbol_string}&token={IEX_CLOUD_API_TOKEN}'
    data = requests.get(batch_api_call_url).json()

    for symbol in symbol_string.split(','):
      final_dataframe1 = final_dataframe1.append(
                                        pd.Series([symbol,
                                                   data[symbol]['quote']['latestPrice'],
                                                   data[symbol]['quote']['marketCap'],
                                                   'N/A'],
                                                  index = my_columns),
                                        ignore_index = True)

# %%
final_dataframe1
# Out:
#     Ticker  Stock Price Market Capitalization Number of Shares to Buy
# 0        A      102.620           30025305955                     N/A
# 1      AAL       10.915            7133395103                     N/A
# 2      AAP       49.930            2969350132                     N/A
# 3     AAPL      167.690         2621704364080                     N/A
# 4     ABBV      137.880          243364636238                     N/A
# ..     ...          ...                   ...                     ...
# 491    YUM      119.650           33527279772                     N/A
# 492    ZBH      102.880           21498230106                     N/A
# 493   ZBRA      206.950           10624474430                     N/A
# 494   ZION       29.435            4360651990                     N/A
# 495    ZTS      155.300           71487215347                     N/A
#
# [496 rows x 4 columns]

# %%
portfolio_value=input('Enter value of your portfolio:')
try:
  portfolio_value=float(portfolio_value)
except:
  print('Enter an integer')
  portfolio_value=input('Enter value of your portfolio:')
  portfolio_value=float(portfolio_value)
# Out:
# Enter value of your portfolio:1000000

# %%
position_size=portfolio_value/final_dataframe1.shape[0]
print(position_size)
# Out:
# 2016.1290322580646

# %%
for i in range(final_dataframe1.shape[0]):
  final_dataframe1.loc[i,'Number of Shares to Buy']=math.floor(position_size/final_dataframe1.loc[i,'Stock Price'])

# %%
final_dataframe1
# Out:
#     Ticker  Stock Price Market Capitalization Number of Shares to Buy
# 0        A      102.620           30025305955                      19
# 1      AAL       10.915            7133395103                     184
# 2      AAP       49.930            2969350132                      40
# 3     AAPL      167.690         2621704364080                      12
# 4     ABBV      137.880          243364636238                      14
# ..     ...          ...                   ...                     ...
# 491    YUM      119.650           33527279772                      16
# 492    ZBH      102.880           21498230106                      19
# 493   ZBRA      206.950           10624474430                       9
# 494   ZION       29.435            4360651990                      68
# 495    ZTS      155.300           71487215347                      12
#
# [496 rows x 4 columns]

# %%
writer = pd.ExcelWriter('recommended_trades.xlsx', engine='xlsxwriter')
final_dataframe1.to_excel(writer, sheet_name='Recommended Trades', index = False)

# %%
background_color = '#0a0a23'
font_color = '#ffffff'

string_format = writer.book.add_format(
        {
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

dollar_format = writer.book.add_format(
        {
            'num_format':'$0.00',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

integer_format = writer.book.add_format(
        {
            'num_format':'0',
            'font_color': font_color,
            'bg_color': background_color,
            'border': 1
        }
    )

# %%
writer.sheets['Recommended Trades'].set_column('A:A', #This tells the method to apply the format to column B
                     18, #This tells the method to apply a column width of 18 pixels
                     string_format #This applies the format 'string_format' to the column
                    )
writer.sheets['Recommended Trades'].set_column('B:B',18,dollar_format)
writer.sheets['Recommended Trades'].set_column('C:C',18,integer_format)
writer.sheets['Recommended Trades'].set_column('D:D',18,dollar_format)
writer.save()

# %%
column_formats = {
                    'A': ['Ticker', string_format],
                    'B': ['Price', dollar_format],
                    'C': ['Market Capitalization', dollar_format],
                    'D': ['Number of Shares to Buy', integer_format]
                    }

for column in column_formats.keys():
    writer.sheets['Recommended Trades'].set_column(f'{column}:{column}', 20, column_formats[column][1])
    writer.sheets['Recommended Trades'].write(f'{column}1', column_formats[column][0], string_format)

# %%
from google.colab import files
files.download('updated.csv')

# %%
final_dataframe1.to_csv('updated.csv')

# %%
writer.close()
